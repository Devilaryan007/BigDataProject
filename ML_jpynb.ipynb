# %% [markdown]
# <a href="https://colab.research.google.com/github/Devilaryan007/BigDataProject/blob/test/ML_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
url ="https://real-time-amazon-data.p.rapidapi.com/product-category-list"
headers = {
	"x-rapidapi-key": "f52706347amsh683ad45c05fc031p17025bjsn82cfc1d6eebe"}
response=requests.get("https://real-time-amazon-data.p.rapidapi.com/product-category-list",headers=headers)
print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'd6fd71b4-d22f-44ff-ae3d-7cfc07eadb47', 'parameters': {'country': 'US'}, 'data': [{'name': 'All Departments', 'id': 'aps'}, {'name': 'Alexa Skills', 'id': 'alexa-skills'}, {'name': 'Amazon Devices', 'id': 'amazon-devices'}, {'name': 'Amazon Explore', 'id': 'live-explorations'}, {'name': 'Amazon Fresh', 'id': 'amazonfresh'}, {'name': 'Amazon Pharmacy', 'id': 'amazon-pharmacy'}, {'name': 'Amazon Warehouse', 'id': 'warehouse-deals'}, {'name': 'Appliances', 'id': 'appliances'}, {'name': 'Apps & Games', 'id': 'mobile-apps'}, {'name': 'Arts, Crafts & Sewing', 'id': 'arts-crafts'}, {'name': 'Audible Books & Originals', 'id': 'audible'}, {'name': 'Automotive Parts & Accessories', 'id': 'automotive'}, {'name': 'AWS Courses', 'id': 'courses'}, {'name': 'Baby', 'id': 'baby-products'}, {'name': 'Beauty & Personal Care', 'id': 'beauty'}, {'name': 'Books', 'id': 'stripbooks'}, {'name': 'CDs & Vinyl', 'id': 'popular'}, {'name': 'Cell Phones & Accessories', 'id': 'mobi
# ...

# %%
df=pd.DataFrame(response.json()['data'])
df.to_csv("amazon_data.csv")

# %%
from bs4 import BeautifulSoup
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Increasing the timeout to 30 seconds to give the server more time
books = requests.get("https://books.toscrape.com/", headers=headers, timeout=30).text
soup = BeautifulSoup(books, 'lxml') # Corrected BeautifulSoup initialization
#print(soup.prettify())
book=soup.find_all("article",class_="product_pod") # Changed 'div' to 'article'
len(book)# Corrected to call find_all directly on the soup object

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

book_titles = []
book_prices = []
book_instock_status = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

base_url = "https://books.toscrape.com/catalogue/page-{}.html"

# Loop through all 50 pages
for page_num in range(1, 51):
  page_url = base_url.format(page_num)
  print(f"Scraping page: {page_url}") # Added print to show progress
  try:
    books_response_text = requests.get(page_url, headers=headers, timeout=30).text
    soup = BeautifulSoup(books_response_text, 'lxml')
    product_pods = soup.find_all("article", class_="product_pod")

    for b in product_pods:
      title = b.find('h3').find('a')['title']
      book_titles.append(title)

      price_tag = b.find('p', class_='price_color')
      price_text = price_tag.text.replace('£', '').replace('Â', '')
      book_prices.append(float(price_text))

      instock_tag = b.find('p', class_='instock availability')
      instock_text = instock_tag.text.strip()
      book_instock_status.append(instock_text)
  except requests.exceptions.RequestException as e:
    print(f"Error scraping {page_url}: {e}")
    continue # Continue to the next page if there's an error

books_df = pd.DataFrame({
    'Title': book_titles,
    'Price': book_prices,
    'Availability': book_instock_status
})
display(books_df.head())
print(f"Total books scraped: {len(books_df)}")
books_df.to_csv('books_data.csv', index=False)

# %%
import requests as re
import pandas as pd

# api_key="5d75f33c8bf993b26540f8749276907c"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1ZDc1ZjMzYzhiZjk5M2IyNjU0MGY4NzQ5Mjc2OTA3YyIsIm5iZiI6MTc4MDkwNTI0NC40NzMsInN1YiI6IjZhMjY3NTFjYjAwM2Y2ZDMyYmI0YzliYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.YJrDqgrW2lGoedqifMxbXtY2OGbnD9ilbczAyHv7Q7M"
}
all_pages_data = []
for page_num in range(1,51):
  url = f"https://api.themoviedb.org/3/movie/changes?page={page_num}"

  response= re.get(url=url,headers=headers)
  print(response.text)
  # Check if 'results' key exists and is not empty
  if response.json() and 'results' in response.json() and response.json()['results']:
    df=pd.DataFrame(response.json()['results'])
    all_pages_data.append(df)
  # print(df.shape)

# Concatenate all dataframes once after the loop
if all_pages_data:
    movie_df=pd.concat(all_pages_data, ignore_index=True)
    # print(movie_df.shape)
else:
    print("No data collected.")

# %%
print(movie_df.head(10))
# Out:
#         id  adult softcore
# 0  1530510  False    False
# 1  1709760  False    False
# 2   617031  False    False
# 3  1709766  False    False
# 4  1709765  False    False
# 5  1123283  False    False
# 6  1665527  False    False
# 7  1699863  False    False
# 8  1373504  False    False
# 9  1207016  False    False
